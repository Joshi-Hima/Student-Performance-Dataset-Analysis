# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshi-Hima/Student-Performance-Dataset-Analysis/blob/main/Student_performence_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/TechAxis(Data Science)/Student_performance_data _.csv')
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
df.isna().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
df[df['Age']>15]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# 5          1006   18       0          0                  1         8.191219
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df['GPA'].max()
# Out:
# 4.0

# %%
df['GradeClass'].max()
# Out:
# 4.0

# %%
gender_1 = df['Gender'] == 1
gender_1.value_counts()
# Out:
# Gender
# True     1222
# False    1170
# Name: count, dtype: int64

# %%
df['StudyTimeWeekly'].agg(['min', 'max'])
# Out:
# min     0.001057
# max    19.978094
# Name: StudyTimeWeekly, dtype: float64

# %%
df['Ethnicity'].value_counts()
# Out:
# Ethnicity
# 0    1207
# 1     493
# 2     470
# 3     222
# Name: count, dtype: int64

# %%
df['Ethnicity'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ethnicity'>

# %%
df['Ethnicity'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#lets see the students in A and A+ category

a_plus = (df['GPA']>3.6) & (df['GPA']<=4)
df[a_plus]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 44         1045   18       1          0                  1        18.921512
# 119        1120   15       0          2                  1        19.565309
# 162        1163   18       0          0                  2        13.084716
# 307        1308   16       1          2                  0         9.926455
# 363        1364   16       0          0                  3         7.873638
# 423        1424   17       1          2                  2         5.621478
# 442        1443   15       0          0                  2        19.424398
# 504        1505   17       1          1                  0        18.751007
# 509        1510   16       1          2                  0        15.361788
# 527        1528   16       1          0                  2         7.105793
# 557        1558   16       1          3                  3        16.202802
# ...

# %%
a_plus.value_counts()
# Out:
# GPA
# False    2353
# True       39
# Name: count, dtype: int64

# %%
a_plus.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GPA'>

# %%
a_plus.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#Lets see the students in A category

a_cate = (df['GPA']>3.2) & (df['GPA']<=3.6)
df[a_cate]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 9          1010   16       1          0                  1        18.444466
# 64         1065   17       0          0                  2        16.388557
# 65         1066   16       0          1                  1        18.111643
# 69         1070   16       1          2                  1         0.941224
# 73         1074   16       0          0                  3        16.248273
# ...         ...  ...     ...        ...                ...              ...
# 2345       3346   18       0          0                  3        12.207877
# 2352       3353   17       1          0                  3        19.777514
# 2358       3359   16       0          0                  2         8.367667
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
#
# ...

# %%
a_cate.value_counts()
# Out:
# GPA
# False    2221
# True      171
# Name: count, dtype: int64

# %%
std_grp_by = df.groupby('StudentID')

# %%
max_absent = df['Absences'].max()
df.loc[max_absent, 'StudentID']
# Out:
# 1030

# %%
#lets see those students who are studying more than 15 hrs a week and bringing A+ marks
more_std_a = (df['StudyTimeWeekly']>=15) & ((df['GPA']>3.6) & (df['GPA']<=4))
df[more_std_a]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 44         1045   18       1          0                  1        18.921512
# 119        1120   15       0          2                  1        19.565309
# 442        1443   15       0          0                  2        19.424398
# 504        1505   17       1          1                  0        18.751007
# 509        1510   16       1          2                  0        15.361788
# 557        1558   16       1          3                  3        16.202802
# 689        1690   16       0          2                  2        19.462894
# 919        1920   18       0          1                  1        18.106437
# 951        1952   18       1          0                  2        18.672308
# 1278       2279   15       1          0                  2        18.899696
# 1435       2436   16       0          0                  1        18.220314
# ...

# %%
more_std_a.value_counts()
# Out:
# False    2377
# True       15
# Name: count, dtype: int64

# %%
more_std_a.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
more_std_a.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# lets see the students who fall under A category and who also likes music and sprots

a_plus_music_sports = ((df['GPA']>3.2) & (df['GPA']<=3.6)) & ((df['Music'] == 1) & (df['Sports'] == 1))
df[a_plus_music_sports]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 284        1285   16       0          0                  3         9.589100
# 330        1331   15       1          2                  1         8.299955
# 447        1448   16       0          0                  2        13.812455
# 456        1457   16       0          1                  4         6.511623
# 568        1569   17       0          0                  1         9.267820
# 776        1777   15       1          2                  1        12.060277
# 1115       2116   17       0          0                  2        13.864191
# 1136       2137   17       1          3                  1         0.583413
# 1227       2228   18       0          0                  3        10.767684
# 1316       2317   16       0          0                  1         9.373033
# 1494       2495   16       1          3                  3        18.943412
# ...

# %%
a_plus_music_sports.value_counts()
# Out:
# False    2376
# True       16
# Name: count, dtype: int64

# %%
a_plus_music_sports.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
a_plus_music_sports.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# lets see the students who fall under A category and who also likes music but don't like sprots

a_plus_music_sports = ((df['GPA']>3.2) & (df['GPA']<=3.6)) & ((df['Music'] == 1) & (df['Sports'] == 0))
df[a_plus_music_sports]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 69         1070   16       1          2                  1         0.941224
# 111        1112   17       1          3                  0         5.670144
# 124        1125   15       0          0                  2         2.580728
# 292        1293   15       1          0                  2        12.283377
# 358        1359   15       1          0                  2        16.808855
# 454        1455   15       1          2                  0         9.772099
# 472        1473   17       1          0                  0         6.391789
# 559        1560   16       0          1                  1        12.676996
# 682        1683   17       0          1                  2         2.727422
# 774        1775   16       1          3                  1        19.004224
# 792        1793   15       1          1                  2         8.406708
# ...

# %%
a_plus_music_sports.value_counts()
# Out:
# False    2360
# True       32
# Name: count, dtype: int64

# %%
a_plus_music_sports.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
a_plus_music_sports.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#lets see the students who are Volunteering

volun = df['Volunteering'] == 1
df[volun]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 8          1009   17       0          0                  0         4.562008
# 11         1012   17       0          0                  1         7.598486
# 18         1019   18       0          1                  3        16.254658
# 20         1021   16       1          0                  3         2.621597
# 31         1032   15       0          0                  3         8.132731
# ...         ...  ...     ...        ...                ...              ...
# 2371       3372   18       1          0                  3         0.668760
# 2375       3376   18       0          0                  2        18.925290
# 2378       3379   15       1          0                  2        12.905555
# 2389       3390   16       1          0                  2         6.805500
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
volun.value_counts()
# Out:
# Volunteering
# False    2016
# True      376
# Name: count, dtype: int64

# %%
volun.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Volunteering'>

# %%
volun.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['ParentalSupport'].value_counts()
# Out:
# ParentalSupport
# 2    740
# 3    697
# 1    489
# 4    254
# 0    212
# Name: count, dtype: int64

# %% [markdown]
# # Parential Support Analysis of the students

# %%
df['ParentalSupport'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='ParentalSupport'>

# %%
df['ParentalSupport'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['GradeClass'].value_counts()
# Out:
# GradeClass
# 4.0    1211
# 3.0     414
# 2.0     391
# 1.0     269
# 0.0     107
# Name: count, dtype: int64

# %%
df['GradeClass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GradeClass'>

# %%
df['GradeClass'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# lets see the parential education analysis
df['ParentalEducation'].value_counts()
# Out:
# ParentalEducation
# 2    934
# 1    728
# 3    367
# 0    243
# 4    120
# Name: count, dtype: int64

# %%
#lets see whose student parental education is the highest

highest_edu = df['ParentalEducation'].max()
df.loc[highest_edu, 'StudentID']
# Out:
# 1005

# %%
#lets see whose the students whose paretal education lies in the highest grade 4

highest_grade_edu = df['ParentalEducation'] == 4
df.loc[highest_grade_edu]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 7          1008   15       1          1                  4        15.424496
# 23         1024   18       1          3                  4        18.946138
# 56         1057   18       1          0                  4         0.921383
# 57         1058   15       0          0                  4        10.877558
# 66         1067   18       0          0                  4         2.395199
# ...         ...  ...     ...        ...                ...              ...
# 2178       3179   17       1          1                  4         1.564842
# 2238       3239   18       0          0                  4         9.356048
# 2243       3244   16       1          3                  4        10.349220
# 2318       3319   17       0          0                  4        12.941403
# 2368       3369   15       0          0                  4         6.682728
#
# ...

# %%
df.loc[highest_grade_edu, 'StudentID']
# Out:
# 7       1008
# 23      1024
# 56      1057
# 57      1058
# 66      1067
#         ...
# 2178    3179
# 2238    3239
# 2243    3244
# 2318    3319
# 2368    3369
# Name: StudentID, Length: 120, dtype: int64

# %%
#lets see the stdents whose parental education is between 0 and 3 and and who fall under A+ category

parent_edu_a_plus = ((df['ParentalEducation']>= 0) & df['ParentalEducation']<=3) & ((df['GPA']>3.6) & (df['GPA']<=4.0))
df[parent_edu_a_plus]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 44         1045   18       1          0                  1        18.921512
# 119        1120   15       0          2                  1        19.565309
# 162        1163   18       0          0                  2        13.084716
# 307        1308   16       1          2                  0         9.926455
# 363        1364   16       0          0                  3         7.873638
# 423        1424   17       1          2                  2         5.621478
# 442        1443   15       0          0                  2        19.424398
# 504        1505   17       1          1                  0        18.751007
# 509        1510   16       1          2                  0        15.361788
# 527        1528   16       1          0                  2         7.105793
# 557        1558   16       1          3                  3        16.202802
# ...

# %%
parent_edu_a_plus.value_counts()
# Out:
# False    2353
# True       39
# Name: count, dtype: int64

# %%
parent_edu_a_plus.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
parent_edu_a_plus.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
